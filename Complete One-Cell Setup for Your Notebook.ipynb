# %%
pwd
# Out:
# '/home/ipashto-ai/Documents/ipashto-glossary-ddup'

# %%
# !tree
# Out:
# .
# ├── Complete One-Cell Setup for Your Notebook.ipynb
# ├── data
# │   ├── ddup_agriculture_farming.json
# │   ├── ddup_agriculture.json
# │   ├── ddup_bazar_marketplace.json
# │   ├── ddup_beverages_drinks.json
# │   ├── ddup_car_types_automotive.json
# │   ├── ddup_chinese_to_pashto_boys_names.json
# │   ├── ddup_chinese_to_pashto_girls_names_meaning.json
# │   ├── ddup_common.json
# │   ├── ddup_cooking.json
# │   ├── ddup_core.json
# │   ├── ddup_countries_capitals.json
# │   ├── ddup_culture_sports.json
# │   ├── ddup_currencies_finance.json
# │   ├── ddup_english_to_pashto_boys_names.json
# │   ├── ddup_english_to_pashto_girls_names.json
# │   ├── ddup_fantasy_mythology.json
# │   ├── ddup_finance_commerce.json
# │   ├── ddup_finance_economics.json
# │   ├── ddup_food_items.json
# │   ├── ddup_geography_continents.json
# │   ├── ddup_grocery_supplies.json
# │   ├── ddup_history_literature.json
# │   ├── ddup_islamic_jurisprudence.json
# ...
